# %% [markdown]
# This is a dataframe giving information on snowfall, maximum temperature and minimum temperature in Seattle
# for different days. The mean snowfall, maximum temperature and minimum temperature are -54, 170 and 87 respectively.
# There are 17 columns in the dataframe. The maximum Temperaturemaximum is 356 and the minimum temperature minimum is
# -60. The notebook also has plots of Maximum Temperature and Minimum Temperature vs days at the end.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Seattle.xlsx")

# %%
df
# Out:
#                STATION                                STATION_NAME      DATE  \
# 0    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140101
# 1    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140102
# 2    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140103
# 3    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140104
# 4    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140105
# 5    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140106
# 6    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140107
# 7    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140108
# 8    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140109
# 9    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140110
# 10   GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140111
# ...

# %% [markdown]
# # Describe df

# %%
df.describe()
# Out:
#                DATE        PRCP        SNWD         SNOW        TMAX  \
# count  3.650000e+02  365.000000  365.000000   365.000000  365.000000
# mean   2.014067e+07   33.775342    0.219178   -54.531507  169.958904
# std    3.454755e+02   67.815757    4.187391   739.171802   72.687242
# min    2.014010e+07    0.000000    0.000000 -9999.000000  -16.000000
# 25%    2.014040e+07    0.000000    0.000000     0.000000  111.000000
# 50%    2.014070e+07    0.000000    0.000000     0.000000  161.000000
# 75%    2.014100e+07   36.000000    0.000000     0.000000  222.000000
# max    2.014123e+07  467.000000   80.000000    74.000000  356.000000
#
#              TMIN        AWND        WDF2         WDF5        WSF2  \
# count  365.000000  365.000000  365.000000   365.000000  365.000000
# mean    86.624658   33.876712  181.657534  -227.232877   75.463014
# std     49.746433   14.398895  101.995505  2027.917682   27.043146
# min    -60.000000    6.000000   10.000000 -9999.000000   31.000000
# ...

# %% [markdown]
# # print first and last 4 rows

# %%
df.head(4)
# Out:
#              STATION                                STATION_NAME      DATE  \
# 0  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140101
# 1  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140102
# 2  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140103
# 3  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140104
#
#    PRCP  SNWD  SNOW  TMAX  TMIN  AWND  WDF2  WDF5  WSF2  WSF5  WT01  WT05  \
# 0     0     0     0    72    33    12   340   310    36    40 -9999 -9999
# 1    41     0     0   106    61    32   190   200    94   116 -9999 -9999
# 2    15     0     0    89    28    26    30    50    63    72     1 -9999
# 3     0     0     0    78     6    27    40    40    45    58     1 -9999
#
#    WT02  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# 3 -9999 -9999

# %%
df.tail(4)
# Out:
#                STATION                                STATION_NAME      DATE  \
# 361  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20141228
# 362  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20141229
# 363  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20141230
# 364  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20141231
#
#      PRCP  SNWD  SNOW  TMAX  TMIN  AWND  WDF2  WDF5  WSF2  WSF5  WT01  WT05  \
# 361    41     0     0    67    28    18    50    30    58    72     1 -9999
# 362     0     0     0    61     6    43   350   350    76   103     1 -9999
# 363     0     0     0    33   -21    36    90    70    63    76 -9999 -9999
# 364     0     0     0    33   -27    30    30 -9999    58 -9999 -9999 -9999
#
#      WT02  WT03
# 361 -9999 -9999
# 362 -9999 -9999
# 363 -9999 -9999
# 364 -9999 -9999

# %% [markdown]
# # Print number of observations in each column

# %%
df.count()
# Out:
# STATION         365
# STATION_NAME    365
# DATE            365
# PRCP            365
# SNWD            365
# SNOW            365
# TMAX            365
# TMIN            365
# AWND            365
# WDF2            365
# WDF5            365
# WSF2            365
# WSF5            365
# WT01            365
# WT05            365
# WT02            365
# WT03            365
# dtype: int64

# %% [markdown]
# # print names of columns

# %%
df.columns.values.tolist()
# Out:
# ['STATION',
#  'STATION_NAME',
#  'DATE',
#  'PRCP',
#  'SNWD',
#  'SNOW',
#  'TMAX',
#  'TMIN',
#  'AWND',
#  'WDF2',
#  'WDF5',
#  'WSF2',
#  'WSF5',
#  'WT01',
#  'WT05',
#  'WT02',
#  'WT03']

# %% [markdown]
# # print number of columns

# %%
len(df.columns)
# Out:
# 17

# %% [markdown]
# # sort by name of a column

# %%
df.sort_values(by = 'TMAX')
# Out:
#                STATION                                STATION_NAME      DATE  \
# 36   GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140206
# 35   GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140205
# 34   GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140204
# 333  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20141130
# 364  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20141231
# 37   GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140207
# 363  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20141230
# 39   GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140209
# 334  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20141201
# 332  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20141129
# 33   GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140203
# ...

# %% [markdown]
# # Drop NaN values

# %%
df.dropna()
# Out:
#                STATION                                STATION_NAME      DATE  \
# 0    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140101
# 1    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140102
# 2    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140103
# 3    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140104
# 4    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140105
# 5    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140106
# 6    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140107
# 7    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140108
# 8    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140109
# 9    GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140110
# 10   GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US  20140111
# ...

# %% [markdown]
# # Find max Tmax and min Tmin

# %%
df['TMAX'].max()
# Out:
# 356

# %%
df['TMIN'].min()
# Out:
# -60

# %% [markdown]
# # Plot TMAX and TMIN

# %%
plt.plot(df['TMAX'])

# %%
plt.show()

# %%
plt.plot(df['TMIN'])
