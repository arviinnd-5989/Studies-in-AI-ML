# %% [markdown]
# This is a dataframe giving information on the states in the United States of America, their abbreviations, their areas
# and their populations. The matching rows of the file state_abbreviations, state_areas and state populations have been merged.
# The mean, maximum and minimum areas 74253 are 656425 and 68 square miles respectively. The dataframe is sorted according to
# areas in ascending order in the notebook. The notebook also has a plot of the areas of the states at the end.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_excel("state_abbrevs.xlsx")

# %%
df2 = pd.read_excel("state_areas.xlsx")

# %%
df3 = pd.read_excel("state_population.xlsx")

# %%
df1
# Out:
#                    state abbreviation
# 0                Alabama           AL
# 1                 Alaska           AK
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA
# 5               Colorado           CO
# 6            Connecticut           CT
# 7               Delaware           DE
# 8   District of Columbia           DC
# 9                Florida           FL
# 10               Georgia           GA
# 11                Hawaii           HI
# 12                 Idaho           ID
# 13              Illinois           IL
# 14               Indiana           IN
# 15                  Iowa           IA
# 16                Kansas           KS
# 17              Kentucky           KY
# 18             Louisiana           LA
# 19                 Maine           ME
# 20               Montana           MT
# 21              Nebraska           NE
# 22                Nevada           NV
# 23         New Hampshire           NH
# ...

# %%
df2
# Out:
#                    state  area (sq. mi)
# 0                Alabama          52423
# 1                 Alaska         656425
# 2                Arizona         114006
# 3               Arkansas          53182
# 4             California         163707
# 5               Colorado         104100
# 6            Connecticut           5544
# 7               Delaware           1954
# 8                Florida          65758
# 9                Georgia          59441
# 10                Hawaii          10932
# 11                 Idaho          83574
# 12              Illinois          57918
# 13               Indiana          36420
# 14                  Iowa          56276
# 15                Kansas          82282
# 16              Kentucky          40411
# 17             Louisiana          51843
# 18                 Maine          35387
# 19              Maryland          12407
# 20         Massachusetts          10555
# 21              Michigan          96810
# ...

# %% [markdown]
# # insert matchning rows of df1 and df2

# %%
table = df1.merge(df2)

# %%
table
# Out:
#                    state abbreviation  area (sq. mi)
# 0                Alabama           AL          52423
# 1                 Alaska           AK         656425
# 2                Arizona           AZ         114006
# 3               Arkansas           AR          53182
# 4             California           CA         163707
# 5               Colorado           CO         104100
# 6            Connecticut           CT           5544
# 7               Delaware           DE           1954
# 8   District of Columbia           DC             68
# 9                Florida           FL          65758
# 10               Georgia           GA          59441
# 11                Hawaii           HI          10932
# 12                 Idaho           ID          83574
# 13              Illinois           IL          57918
# 14               Indiana           IN          36420
# 15                  Iowa           IA          56276
# 16                Kansas           KS          82282
# ...

# %% [markdown]
# # print mean, max and minimum area

# %%
table['area (sq. mi)'].max()
# Out:
# 656425

# %%
table['area (sq. mi)'].min()
# Out:
# 68

# %%
table['area (sq. mi)'].mean()
# Out:
# 74252.62745098039

# %% [markdown]
# # describe df

# %%
table.describe()
# Out:
#        area (sq. mi)
# count      51.000000
# mean    74252.627451
# std     95854.667975
# min        68.000000
# 25%     35903.500000
# 50%     56276.000000
# 75%     84239.000000
# max    656425.000000

# %% [markdown]
# # Sort by area

# %%
table.sort_values(by = 'area (sq. mi)')
# Out:
#                    state abbreviation  area (sq. mi)
# 8   District of Columbia           DC             68
# 39          Rhode Island           RI           1545
# 7               Delaware           DE           1954
# 6            Connecticut           CT           5544
# 24            New Jersey           NJ           8722
# 23         New Hampshire           NH           9351
# 45               Vermont           VT           9615
# 33         Massachusetts           MA          10555
# 11                Hawaii           HI          10932
# 32              Maryland           MD          12407
# 48         West Virginia           WV          24231
# 40        South Carolina           SC          32007
# 19                 Maine           ME          35387
# 14               Indiana           IN          36420
# 17              Kentucky           KY          40411
# 42             Tennessee           TN          42146
# 46              Virginia           VA          42769
# ...

# %% [markdown]
# # Plot areas

# %%
plt.plot(table['area (sq. mi)'])

# %%
df3
# Out:
#      state/region     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# 5              AL    total  2011    4801627.0
# 6              AL    total  2009    4757938.0
# 7              AL  under18  2009    1134192.0
# 8              AL  under18  2013    1111481.0
# 9              AL    total  2013    4833722.0
# 10             AL    total  2007    4672840.0
# 11             AL  under18  2007    1132296.0
# 12             AL    total  2008    4718206.0
# 13             AL  under18  2008    1134927.0
# 14             AL    total  2005    4569805.0
# 15             AL  under18  2005    1117229.0
# 16             AL    total  2006    4628981.0
# 17             AL  under18  2006    1126798.0
# 18             AL    total  2004    4530729.0
# ...

# %%
df1.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
df2.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
table.head()
# Out:
#         state abbreviation  area (sq. mi)
# 0     Alabama           AL          52423
# 1      Alaska           AK         656425
# 2     Arizona           AZ         114006
# 3    Arkansas           AR          53182
# 4  California           CA         163707

# %%
df3
# Out:
#      state/region     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# 5              AL    total  2011    4801627.0
# 6              AL    total  2009    4757938.0
# 7              AL  under18  2009    1134192.0
# 8              AL  under18  2013    1111481.0
# 9              AL    total  2013    4833722.0
# 10             AL    total  2007    4672840.0
# 11             AL  under18  2007    1132296.0
# 12             AL    total  2008    4718206.0
# 13             AL  under18  2008    1134927.0
# 14             AL    total  2005    4569805.0
# 15             AL  under18  2005    1117229.0
# 16             AL    total  2006    4628981.0
# 17             AL  under18  2006    1126798.0
# 18             AL    total  2004    4530729.0
# ...

# %% [markdown]
# # Data Munging

# %%
df4 = df3.rename(columns = {'state/region' : 'abbreviation'})

# %%
df4
# Out:
#      abbreviation     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# 5              AL    total  2011    4801627.0
# 6              AL    total  2009    4757938.0
# 7              AL  under18  2009    1134192.0
# 8              AL  under18  2013    1111481.0
# 9              AL    total  2013    4833722.0
# 10             AL    total  2007    4672840.0
# 11             AL  under18  2007    1132296.0
# 12             AL    total  2008    4718206.0
# 13             AL  under18  2008    1134927.0
# 14             AL    total  2005    4569805.0
# 15             AL  under18  2005    1117229.0
# 16             AL    total  2006    4628981.0
# 17             AL  under18  2006    1126798.0
# 18             AL    total  2004    4530729.0
# ...

# %% [markdown]
# # merge three tables above

# %%
df5 = pd.merge(table,df4)

# %%
df5
# Out:
#         state abbreviation  area (sq. mi)     ages  year  population
# 0     Alabama           AL          52423  under18  2012   1117489.0
# 1     Alabama           AL          52423    total  2012   4817528.0
# 2     Alabama           AL          52423  under18  2010   1130966.0
# 3     Alabama           AL          52423    total  2010   4785570.0
# 4     Alabama           AL          52423  under18  2011   1125763.0
# 5     Alabama           AL          52423    total  2011   4801627.0
# 6     Alabama           AL          52423    total  2009   4757938.0
# 7     Alabama           AL          52423  under18  2009   1134192.0
# 8     Alabama           AL          52423  under18  2013   1111481.0
# 9     Alabama           AL          52423    total  2013   4833722.0
# 10    Alabama           AL          52423    total  2007   4672840.0
# 11    Alabama           AL          52423  under18  2007   1132296.0
# 12    Alabama           AL          52423    total  2008   4718206.0
# ...
