# %% [markdown]
# This is a dataframe giving information on heights of different presidents of the United States of America.
# The mean, maximum and minimum heights are 180, 193 and 163 centimeters respectively. There are 42 observations
# in each column. The dataframe is sorted according to heights in the notebook. The notebook also has a plot of
# the heights of the presidents at the end.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("President.xlsx")

# %%
df
# Out:
#     order                    name  height(cm)
# 0       1       George Washington         189
# 1       2              John Adams         170
# 2       3        Thomas Jefferson         189
# 3       4           James Madison         163
# 4       5            James Monroe         183
# 5       6       John Quincy Adams         171
# 6       7          Andrew Jackson         185
# 7       8        Martin Van Buren         168
# 8       9  William Henry Harrison         173
# 9      10              John Tyler         183
# 10     11           James K. Polk         173
# 11     12          Zachary Taylor         173
# 12     13        Millard Fillmore         175
# 13     14         Franklin Pierce         178
# 14     15          James Buchanan         183
# 15     16         Abraham Lincoln         193
# 16     17          Andrew Johnson         178
# 17     18        Ulysses S. Grant         173
# 18     19     Rutherford B. Hayes         174
# ...

# %% [markdown]
# # describe df

# %%
df.describe()
# Out:
#            order  height(cm)
# count  42.000000   42.000000
# mean   22.476190  179.738095
# std    13.152461    7.015869
# min     1.000000  163.000000
# 25%    11.250000  174.250000
# 50%    22.000000  182.000000
# 75%    33.750000  183.000000
# max    44.000000  193.000000

# %% [markdown]
# # print first and last four rows

# %%
df.head(4)
# Out:
#    order               name  height(cm)
# 0      1  George Washington         189
# 1      2         John Adams         170
# 2      3   Thomas Jefferson         189
# 3      4      James Madison         163

# %%
df.tail(4)
# Out:
#     order               name  height(cm)
# 38     41  George H. W. Bush         188
# 39     42       Bill Clinton         188
# 40     43     George W. Bush         182
# 41     44       Barack Obama         185

# %% [markdown]
# # print number of observations in each column

# %%
df.count()
# Out:
# order         42
# name          42
# height(cm)    42
# dtype: int64

# %% [markdown]
# # Print names of columns

# %%
df.columns.values.tolist()
# Out:
# ['order', 'name', 'height(cm)']

# %% [markdown]
# # print number of columns

# %%
len(df.columns)
# Out:
# 3

# %% [markdown]
# # sort by name of a column

# %%
df.sort_values(by = 'height(cm)')
# Out:
#     order                    name  height(cm)
# 3       4           James Madison         163
# 7       8        Martin Van Buren         168
# 21     23       Benjamin Harrison         168
# 1       2              John Adams         170
# 22     25        William McKinley         170
# 5       6       John Quincy Adams         171
# 8       9  William Henry Harrison         173
# 10     11           James K. Polk         173
# 11     12          Zachary Taylor         173
# 17     18        Ulysses S. Grant         173
# 18     19     Rutherford B. Hayes         174
# 12     13        Millard Fillmore         175
# 30     33         Harry S. Truman         175
# 36     39            Jimmy Carter         177
# 16     17          Andrew Johnson         178
# 13     14         Franklin Pierce         178
# 23     26      Theodore Roosevelt         178
# 27     30         Calvin Coolidge         178
# 31     34    Dwight D. Eisenhower         179
# ...

# %% [markdown]
# # Find Max and Min height

# %%
df['height(cm)'].max()
# Out:
# 193

# %%
df['height(cm)'].min()
# Out:
# 163

# %% [markdown]
# # Plot heights

# %%
plt.plot(df['height(cm)'])
