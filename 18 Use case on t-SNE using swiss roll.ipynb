# %% [markdown]
# # t - SNE

# %% [markdown]
# This is a use case on t-SNE. We first generate a dataset with 1500 samples using make_swiss_roll. Then, we apply t-SNE and plot the data. We generate a dataset with 300 samples and some noise using make_swiss_roll. We then plot the data and visualize the results.

# %%
# 1. Generate the dataset using make swiss roll and plot the data

# %%
from sklearn.datasets import make_swiss_roll
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
Axes3D
# Out:
# mpl_toolkits.mplot3d.axes3d.Axes3D

# %%
X, color = datasets.samples_generator.make_swiss_roll(n_samples=1500)

# %%
fig = plt.figure()
ax = fig.add_subplot(211, projection='3d')
ax.scatter(X[:,0],X[:,1],X[:,2],c = color)

# %%
X.shape
# Out:
# (1500, 3)

# %%
color.shape
# Out:
# (1500,)

# %%
# 2. Apply t-SNE and plot the data

# %%
from sklearn import manifold, datasets
from sklearn.manifold import TSNE

# %%
tsne = TSNE(random_state=0,perplexity=100)
X1 = tsne.fit_transform(X)

# %%
X1
# Out:
# array([[ 17.531221 ,  11.279646 ],
#        [ -8.303774 ,   8.651795 ],
#        [ -3.1849136,  13.737053 ],
#        ...,
#        [  3.2243388,   6.5173407],
#        [-11.077485 ,  -4.7777557],
#        [-13.298761 , -11.899687 ]], dtype=float32)

# %%
X1.shape
# Out:
# (1500, 2)

# %%
cm = plt.cm.get_cmap('RdYlBu')
plt.figure(figsize=(12,10))
cb = plt.scatter(X1[:,0],X1[:,1], c = color,marker='o', s=15)
plt.colorbar(cb)
plt.legend(prop={'size':15})
plt.title('t-SNE embedding of train & test data', fontsize=20)
plt.title('t-SNE embedding of data', fontsize=20)
# Out:
# No handles with labels found to put in legend.
# Text(0.5,1,'t-SNE embedding of data')

# %%
# 3. Generate 300 samples with noise and plot the data

# %%
X2, color2 = datasets.samples_generator.make_swiss_roll(n_samples=300, noise = 0.3)

# %%
X2.shape
# Out:
# (300, 3)

# %%
#.3. B. Plot the data

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X2[:,0],X2[:,1],X2[:,2],c = color2)

# %%
# Apply t-SNE and plot the data

# %%
tsne2 = TSNE(random_state=0,perplexity=100)
X3 = tsne.fit_transform(X2)

# %%
cm = plt.cm.get_cmap('RdYlBu')
plt.figure(figsize=(12,10))
cb = plt.scatter(X3[:,0],X3[:,1], c = color2,marker='o', s=15)
plt.colorbar(cb)
plt.legend(prop={'size':15})
plt.title('t-SNE embedding of train & test data', fontsize=20)
plt.title('t-SNE embedding of data', fontsize=20)
# Out:
# No handles with labels found to put in legend.
# Text(0.5,1,'t-SNE embedding of data')
